# %%
from linear_regression import LinearRegressionScratch
from sample_data_linear_reg import create_sample_data
from scaler import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Data 
X, y = create_sample_data()

df = pd.DataFrame({
    "X": X.flatten(),
    "y": y
})

df.head()
# Out:
#           X         y
# 0  0.749080  6.334288
# 1  1.901429  9.405278
# 2  1.463988  8.483724
# 3  1.197317  5.604382
# 4  0.312037  4.716440

# %%
# Linear Regression Implementation

# Load data
X, y = create_sample_data()

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train model
model = LinearRegressionScratch(learning_rate=0.1, n_iter=1000, verbose=True)
model.fit(X_scaled, y)

# Predictions
y_pred = model.predict(X_scaled)

# Evaluation
r2 = model.r2_score(y, y_pred)
print("R2 Score:", r2)
print("Predictions:", y_pred)

# Visualization
idx = np.argsort(X[:, 0])
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label="Actual data")
plt.plot(X[idx], y_pred[idx], color="red", label="Regression line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression from Scratch")
plt.legend()
plt.show()

# Loss curve
plt.plot(model.losses)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss vs Iterations")
plt.show()
# Out:
# Iteration 0, Loss: 25.0042
# Iteration 100, Loss: 0.4033
# Iteration 200, Loss: 0.4033
# Iteration 300, Loss: 0.4033
# Iteration 400, Loss: 0.4033
# Iteration 500, Loss: 0.4033
# Iteration 600, Loss: 0.4033
# Iteration 700, Loss: 0.4033
# Iteration 800, Loss: 0.4033
# Iteration 900, Loss: 0.4033
# R2 Score: 0.7692735413614223
# Predictions: [6.29013335 9.48226901 8.27050859 7.53179992 5.07947481 5.07934118
#  4.53689254 9.01390843 7.54540964 8.13797881 4.32913892 9.58861669
#  8.82701716 5.39150298 5.22244771 5.23119873 5.90066718 7.12236579
#  6.60816951 5.82857164 7.60489995 4.98792378 5.83364376 6.24482385
#  6.74182729 8.56514904 5.32133419 7.06407156 7.49720721 4.47244198
#  7.58103241 5.15983847 4.57549673 9.47213722 9.5649166  8.69380079
#  5.90272552 4.75622182 8.00590229 6.65364079 4.89121565 6.95848853
#  4.40561636 9.25293739 5.64879594 7.88561985 5.94204621 7.09639093
#  7.24399508 5.23923176 9.58681487 8.50950778 9.42013335 9.1726426
# ...
